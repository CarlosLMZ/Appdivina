# %%
import random as rd
import Solomod
import Player2mod
import openpyxl as pxl
import matplotlib.pyplot as mpl 
import getpass
import pandas as pd
import numpy as np
import math
import Log2num
import StatsMod
import GuardarExcelMod

print("Bienvenidos a Appdivina.")

def Menu():
    opcion1 = print("1. Partida modo solitario")
    opcion2 = print("2. Partida 2 Jugadores")
    opcion3 = print("3. Estadísticas")
    opcion4 = print("4. Consejos básicos")
    opcion5 = print("5. Salir")

def Prueba():
    while True:
        Menu()
        opcion = int(input("Por favor, selecciona una opción válida del Menú: "))
        
        if opcion == 1:
            Solomod.Solo()
        elif opcion == 2:
            Player2mod.Players2()
        elif opcion == 3:
            StatsMod.ScriptStats()
        elif opcion == 4:
            Log2num.Consejo()
        elif opcion == 5:
            print("¡Hasta la próxima!")
            break

Prueba()

# No he establecido distintos números según dificultad porque la dificultad ya viene establecida según el número de intentos
# Según cómo he desarrollado las funciones, se podría tocar el rango sin problema, pero no me parecía necesario teniendo en cuenta el comentario anterior
# Definí num2 = 0 fuera del bucle while para evitar el error de no poder acceder variable local

# Se me hizo más sencillo usar pandas para la parte de datos, pero me gustaría recibir feedback sobre cómo hacer el punto de "estadística" solo usando openpyxl

#Hay algún comentario en cada módulo

# No me hace especial ilusión tener un while True, pero al principio del proyecto no conseguía volver al menú. La otra alternativa que probé fue
# meter todo el código principal dentro de una función (def Main()) y luego terminar llamando a la función (Main()), pero me parece mucho más engorroso.
# Out:
# Bienvenidos a Appdivina.
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadísticas
# 4. Consejos básicos
# 5. Salir
# Por favor, selecciona una opción válida del Menú:  1
# 1. Fácil (20 intentos)
# 2. Medio (12 intentos)
# 3. Difícil (5 intentos)
# Por favor, selecciona una opción válida del Menú:  3
# Adivina el número:
#  500
# El número que buscas es mayor
# Adivina el número:
#  750
# El número que buscas es mayor
# Adivina el número:
#  867
# El número que buscas es menor
# Adivina el número:
#  798
# El número que buscas es mayor
# Adivina el número:
#  813
# Has perdido. El número que buscabas era 799
# Introduce tu nombre:  Pedro
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadísticas
# 4. Consejos básicos
# 5. Salir
# Por favor, selecciona una opción válida del Menú:  2
# 1. Fácil (20 intentos)
# 2. Medio (12 intentos)
# 3. Difícil (5 intentos)
# Por favor, selecciona una opción válida del Menú:  3
# ...
